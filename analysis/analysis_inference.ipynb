# %%
import pandas as pd
import re
import json
import traceback
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Layer
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Embedding, LSTM, Input, Bidirectional, Concatenate, Dropout, Attention
from tensorflow.keras import backend as K

# %%
class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_out_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>', U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)
            if verbose:
                print('Ws+Uh>', Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
def expand_contractions_and_clean(text):
    # mapping of contractions to their expanded forms
    contractions = {
        r"i'm": "i am",
        r"he's": "he is",
        r"she's": "she is",
        r"that's": "that is",
        r"what's": "what is",
        r"where's": "where is",
        r"\'ll": " will",
        r"\'ve": " have",
        r"\'re": " are",
        r"\'d": " would",
        r"won't": "will not",
        r"can't": "can not",
    }
    
    text = text.lower()
    
    # expand contractions
    for contraction, expansion in contractions.items():
        text = re.sub(contraction, expansion, text)
    
    # remove punctuation
    text = re.sub(r"[^\w\s]", "", text)
    
    return text

# %%
model = load_model('../attention/chatbot.h5', custom_objects={'AttentionLayer': AttentionLayer})
model.summary()
# Out:
# 2024-06-11 12:22:29.769536: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-11 12:22:29.769713: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  decoder_input_layer (InputLaye  [(None, 23)]        0           []
#  r)
#
#  encoder_input_layer (InputLaye  [(None, 23)]        0           []
#  r)
#
#  embedding (Embedding)          (None, 23, 100)      965800      ['encoder_input_layer[0][0]',
#                                                                   'decoder_input_layer[0][0]']
#
#  encoder_bidirectional_lstm (Bi  [(None, 23, 512),   731136      ['embedding[0][0]']
#  directional)                    (None, 256),
#                                  (None, 256),
#                                  (None, 256),
#                                  (None, 256)]
#
#  state_h_concat (Concatenate)   (None, 512)          0           ['encoder_bidirectional_lstm[0][1
#                                                                  ]',
#                                                                   'encoder_bidirectional_lstm[0][3
#                                                                  ]']
#
#  state_c_concat (Concatenate)   (None, 512)          0           ['encoder_bidirectional_lstm[0][2
#                                                                  ]',
#                                                                   'encoder_bidirectional_lstm[0][4
#                                                                  ]']
#
#  decoder_lstm_layer (LSTM)      [(None, 23, 512),    1255424     ['embedding[1][0]',
#                                  (None, 512),                     'state_h_concat[0][0]',
#                                  (None, 512)]                     'state_c_concat[0][0]']
#
#  attention_layer (AttentionLaye  ((None, 23, 512),   524800      ['encoder_bidirectional_lstm[0][0
#  r)                              (None, 23, 23))                 ]',
#                                                                   'decoder_lstm_layer[0][0]']
#
#  decoder_concat_input_layer (Co  (None, 23, 1024)    0           ['decoder_lstm_layer[0][0]',
#  ncatenate)                                                       'attention_layer[0][0]']
#
#  decoder_dense_layer (Dense)    (None, 23, 9657)     9898425     ['decoder_concat_input_layer[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 13,375,585
# Trainable params: 13,375,585
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#load model history
with open('../attention/chatbot_history.json', 'r') as f:
    history = json.load(f)

# %%
plt.plot(history['sparse_categorical_accuracy'], label='accuracy')
plt.plot(history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
#load vocab
with open('../attention/vocab.json', 'r', encoding='utf-8') as f:
    vocab = json.load(f)
    
inverse_vocab = {count: word for word, count in vocab.items()}
len(vocab)
# Out:
# 9657

# %%
MAX_LENGTH = 23
LSTM_UNITS = 256
EMBEDDING_DIMENSION = 100
VOCAB_SIZE = len(vocab)

# %%
embedding_index = {}
with open('../dataset/glove/glove.6B.100d.txt', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = coefs
    f.close()

print("GloVe Loded!")
# Out:
# GloVe Loded!

# %%
def embedding_matrix_creater(dimension, word_index):
    embedding_matrix = np.zeros((len(word_index)+1, dimension))
    for word, i in word_index.items():
        embedding_vector = embedding_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    return embedding_matrix

embedding_matrix = embedding_matrix_creater(dimension=EMBEDDING_DIMENSION, word_index=vocab)

# %%
embedding_layer = Embedding(VOCAB_SIZE+1, 
                  EMBEDDING_DIMENSION, 
                  input_length=MAX_LENGTH,
                  trainable=True)

embedding_layer.build((None,))
embedding_layer.set_weights([embedding_matrix])

# %%
#building model
encoder_input_layer = Input(shape=(MAX_LENGTH, ), name='encoder_input_layer')

encoder_embedding_layer = embedding_layer(encoder_input_layer)
encoder_bidirectional_lstm_layer = Bidirectional(LSTM(LSTM_UNITS, return_state=True, dropout=0.05, return_sequences = True, name='encoder_lstm_layer'), name='encoder_bidirectional_lstm')

encoder_outputs, forward_h, forward_c, backward_h, backward_c = encoder_bidirectional_lstm_layer(encoder_embedding_layer)

state_h = Concatenate(name='state_h_concat')([forward_h, backward_h])
state_c = Concatenate(name='state_c_concat')([forward_c, backward_c])

encoder_states = [state_h, state_c]

decoder_input_layer = Input(shape=(MAX_LENGTH, ), name='decoder_input_layer')
decoder_embedding_layer = embedding_layer(decoder_input_layer)
decoder_lstm_layer = LSTM(LSTM_UNITS * 2, return_state=True, return_sequences=True, dropout=0.05, name='decoder_lstm_layer')
decoder_outputs, _, _ = decoder_lstm_layer(decoder_embedding_layer, initial_state=encoder_states)

# attention
attention_layer = AttentionLayer(name='attention_layer')
attention_output, attention_state = attention_layer([encoder_outputs, decoder_outputs])
decoder_concat_input_layer = Concatenate(axis=-1, name='decoder_concat_input_layer')([decoder_outputs, attention_output])

decoder_dense_layer = Dense(VOCAB_SIZE, activation='softmax', name='decoder_dense_layer')
final_output_layer = decoder_dense_layer(decoder_concat_input_layer)

model = Model([encoder_input_layer, decoder_input_layer], final_output_layer)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  decoder_input_layer (InputLaye  [(None, 23)]        0           []
#  r)
#
#  encoder_input_layer (InputLaye  [(None, 23)]        0           []
#  r)
#
#  embedding (Embedding)          (None, 23, 100)      965800      ['encoder_input_layer[0][0]',
#                                                                   'decoder_input_layer[0][0]']
#
#  encoder_bidirectional_lstm (Bi  [(None, 23, 512),   731136      ['embedding[0][0]']
#  directional)                    (None, 256),
#                                  (None, 256),
#                                  (None, 256),
#                                  (None, 256)]
#
#  state_h_concat (Concatenate)   (None, 512)          0           ['encoder_bidirectional_lstm[0][1
#                                                                  ]',
#                                                                   'encoder_bidirectional_lstm[0][3
#                                                                  ]']
#
#  state_c_concat (Concatenate)   (None, 512)          0           ['encoder_bidirectional_lstm[0][2
#                                                                  ]',
#                                                                   'encoder_bidirectional_lstm[0][4
#                                                                  ]']
#
#  decoder_lstm_layer (LSTM)      [(None, 23, 512),    1255424     ['embedding[1][0]',
#                                  (None, 512),                     'state_h_concat[0][0]',
#                                  (None, 512)]                     'state_c_concat[0][0]']
#
#  attention_layer (AttentionLaye  ((None, 23, 512),   524800      ['encoder_bidirectional_lstm[0][0
#  r)                              (None, 23, 23))                 ]',
#                                                                   'decoder_lstm_layer[0][0]']
#
#  decoder_concat_input_layer (Co  (None, 23, 1024)    0           ['decoder_lstm_layer[0][0]',
#  ncatenate)                                                       'attention_layer[0][0]']
#
#  decoder_dense_layer (Dense)    (None, 23, 9657)     9898425     ['decoder_concat_input_layer[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 13,375,585
# Trainable params: 13,375,585
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#load saved_weights
model.load_weights('../attention/chatbot_weights.h5')

# %%
#model inference for generating responses
inference_encoder_model = Model(encoder_input_layer, [encoder_outputs, encoder_states])

inference_decoder_state_input_h = Input(shape=( LSTM_UNITS * 2,))
inference_decoder_state_input_c = Input(shape=( LSTM_UNITS * 2,))

inference_decoder_states_inputs = [inference_decoder_state_input_h, inference_decoder_state_input_c]


inference_decoder_outputs, inference_state_h, inference_state_c = decoder_lstm_layer(decoder_embedding_layer , initial_state=inference_decoder_states_inputs)


inference_decoder_states = [inference_state_h, inference_state_c]

inference_decoder_model = Model(
    [decoder_input_layer, inference_decoder_states_inputs],
    [inference_decoder_outputs] + inference_decoder_states
)

# %%
analysis_dataset = pd.read_csv('analysis_prompts.csv')
analysis_dataset.head()
# Out:
#                                               prompt    context
# 0  Bombed the presentation. Feeling terrified of ...  Terrified
# 1   Aced a difficult exam! Feeling joyful and proud.     Joyful
# 2            Feeling lonely and isolated in my dorm.     Lonely
# 3            Grateful for the support of my friends.   Grateful
# 4  Feeling disgusted by a mess someone left in th...  Disgusted

# %%
responses = []
for index, row in analysis_dataset.iterrows():
    try:
        print('PROMPT: ', row['prompt'])
        
        input_cleaned = expand_contractions_and_clean(row['prompt'].strip()) + ' <SEP> ' + row['context'].lower().strip()
        input_cleaned = [input_cleaned]
        
        text = []
        for x in input_cleaned:
            lst = []
            for y in x.split():
                try:
                    lst.append(vocab[y])
                except:
                    lst.append(vocab['<OUT>'])
            text.append(lst)
        text = pad_sequences(text, MAX_LENGTH, padding='post')

        inference_encoder_output, inference_encoder_states = inference_encoder_model.predict( text )

        empty_target_seq = np.zeros( ( 1 , 1) )
        empty_target_seq[0, 0] = vocab['<SOS>']
        stop_condition = False
        decoded_translation = ''

        while not stop_condition :
            inference_decoder_outputs , h , c = inference_decoder_model.predict([ empty_target_seq ] + inference_encoder_states )

            #attention part
            inference_attention_output, inference_attention_states = attention_layer([inference_encoder_output, inference_decoder_outputs])
            inference_decoder_concat_input = Concatenate(axis=-1)([inference_decoder_outputs, inference_attention_output])
            inference_decoder_concat_input = decoder_dense_layer(inference_decoder_concat_input)

            sampled_word_index = np.argmax( inference_decoder_concat_input[0, -1, :] )
            sampled_word = inverse_vocab[sampled_word_index] + ' '

            if sampled_word != '<EOS> ':
                decoded_translation += sampled_word           

            if sampled_word == '<EOS> ' or len(decoded_translation.split()) > MAX_LENGTH:
                stop_condition = True

            empty_target_seq = np.zeros( ( 1 , 1 ) )  
            empty_target_seq[ 0 , 0 ] = sampled_word_index
            inference_encoder_states = [ h , c ] 

        print("CHATBOT : ", decoded_translation )
        responses.append(decoded_translation)
    except Exception as e:
        #print("I couldn't get you. Please try again.")
        print(e)
# Out:
# PROMPT:  Bombed the presentation. Feeling terrified of failing the class.
# 2024-06-11 12:22:36.129007: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-06-11 12:22:36.320893: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-06-11 12:22:36.852868: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-06-11 12:22:36.862574: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 2s 2s/step
# WARNING:tensorflow:Model was constructed with shape (None, 23) for input KerasTensor(type_spec=TensorSpec(shape=(None, 23), dtype=tf.float32, name='decoder_input_layer'), name='decoder_input_layer', description="created by layer 'decoder_input_layer'"), but it was called on an input with incompatible shape (None, 1).
# 2024-06-11 12:22:38.596219: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-06-11 12:22:38.709558: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 906ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am glad you are okay
# PROMPT:  Aced a difficult exam! Feeling joyful and proud.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i know_comma_ i felt so bad for the first time
# PROMPT:  Feeling lonely and isolated in my dorm.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am sorry to hear that
# PROMPT:  Grateful for the support of my friends.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will be happy for the best
# PROMPT:  Feeling disgusted by a mess someone left in the shared kitchen.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# CHATBOT :  can not even if i found a hair in it
# PROMPT:  Feeling excited about the upcoming semester.
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am excited for the new super smash bros
# PROMPT:  Didn't study enough for an upcoming exam. Feeling unprepared.
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# CHATBOT :  i was so nervous and ready to get my grades back
# PROMPT:  Feeling jealous of a classmate's perfect grades.
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Feeling anxious about a group project presentation.
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will be getting it
# PROMPT:  Feeling content after finishing a long study session.
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am feeling very happy and relieved to go to the pharmacy to start
# PROMPT:  Feeling disappointed about a bad grade on a paper.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will have a good time
# PROMPT:  Professor complimented my participation in class. Feeling proud.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am happy for you
# PROMPT:  Feeling overwhelmed with the workload this semester.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Lost my student ID. Feeling frustrated and worried.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  how much did you get
# PROMPT:  Feeling hopeful about the future after a successful internship.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i hope so i think i will get the job
# PROMPT:  Feeling apprehensive about meeting my professor's office hours.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 12ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Feeling guilty about procrastinating on an assignment.
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i feel so bad about myself
# PROMPT:  Feeling surprised by a surprise quiz in class.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# CHATBOT :  i was shocked by a friend of mine recently
# PROMPT:  Feeling nostalgic about memories from high school.
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i was feeling good about my childhood and high school
# PROMPT:  Feeling confident about my upcoming presentation.
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will do great
# PROMPT:  Feeling furious about a professor's unfair grading policy.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# CHATBOT :  i dont know why they are just being rude and they are just rude to the <OUT>
# PROMPT:  Feeling disappointed after a friend cancels plans.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am going to be a bit more <OUT> but i am stuck at work
# PROMPT:  Feeling caring towards a classmate who is struggling.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  that is awesome i wish i could be more than a year
# PROMPT:  Feeling trusting towards my professor's guidance.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am glad you are okay
# PROMPT:  Feeling disgusted by a rude comment from a classmate.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  what kind of food do you have
# PROMPT:  Feeling apprehensive about starting a new class.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Feeling anxious about making new friends on campus.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Feeling hopeful about my chances of getting a scholarship.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am sure you will be proud of your future
# PROMPT:  Feeling content with my decision to major in this subject.
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  that is great to hear
# PROMPT:  Feeling impressed by a classmate's insightful presentation.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  that is great i bet she is doing better
# PROMPT:  Feeling frustrated about a technical issue during an online exam.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am sure it was a good thing
# PROMPT:  Feeling devastated after a close friend moves away.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  that is sad i am sorry to hear that
# PROMPT:  Bombed the presentation. Feeling terrified of failing the class.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am glad you are okay
# PROMPT:  Aced a difficult exam! Feeling joyful and proud.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i know_comma_ i felt so bad for the first time
# PROMPT:  Feeling lonely and isolated in my dorm.
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# CHATBOT :  i am sorry to hear that
# PROMPT:  Grateful for the support of my friends.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will be happy for the best
# PROMPT:  Feeling disgusted by a mess someone left in the shared kitchen.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  can not even if i found a hair in it
# PROMPT:  Feeling excited about the upcoming semester.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am excited for the new super smash bros
# PROMPT:  Didn't study enough for an upcoming exam. Feeling unprepared.
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# CHATBOT :  i was so nervous and ready to get my grades back
# PROMPT:  Feeling jealous of a classmate's perfect grades.
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Feeling anxious about a group project presentation.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will be getting it
# PROMPT:  Feeling content after finishing a long study session.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am feeling very happy and relieved to go to the pharmacy to start
# PROMPT:  Feeling disappointed about a bad grade on a paper.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will have a good time
# PROMPT:  Professor complimented my participation in class. Feeling proud.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am happy for you
# PROMPT:  Feeling overwhelmed with the workload this semester.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Lost my student ID. Feeling frustrated and worried.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  how much did you get
# PROMPT:  Feeling hopeful about the future after a successful internship.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i hope so i think i will get the job
# PROMPT:  Feeling apprehensive about meeting my professor's office hours.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Feeling guilty about procrastinating on an assignment.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i feel so bad about myself
# PROMPT:  Feeling surprised by a surprise quiz in class.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i was shocked by a friend of mine recently
# PROMPT:  Feeling nostalgic about memories from high school.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i was feeling good about my childhood and high school
# PROMPT:  Feeling confident about my upcoming presentation.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am sure you will do great
# PROMPT:  Feeling furious about a professor's unfair grading policy.
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i dont know why they are just being rude and they are just rude to the <OUT>
# PROMPT:  Feeling disappointed after a friend cancels plans.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am going to be a bit more <OUT> but i am stuck at work
# PROMPT:  Feeling caring towards a classmate who is struggling.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  that is awesome i wish i could be more than a year
# PROMPT:  Feeling trusting towards my professor's guidance.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am glad you are okay
# PROMPT:  Feeling disgusted by a rude comment from a classmate.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  what kind of food do you have
# PROMPT:  Feeling apprehensive about starting a new class.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Feeling anxious about making new friends on campus.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Feeling hopeful about my chances of getting a scholarship.
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am sure you will be proud of your future
# PROMPT:  Feeling content with my decision to major in this subject.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  that is great to hear
# PROMPT:  Feeling impressed by a classmate's insightful presentation.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  that is great i bet she is doing better
# PROMPT:  Feeling frustrated about a technical issue during an online exam.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am sure it was a good thing
# PROMPT:  Feeling devastated after a close friend moves away.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  that is sad i am sorry to hear that
# PROMPT:  Witnessed a classmate being bullied. Feeling angry and...
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  can be so hard to deal with
# PROMPT:  Professor cancelled class last minute. Feeling annoyed and...
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am sorry to hear that
# PROMPT:  Roommate borrowed my notes and didn't return them. Feeling frustrated and...
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  report him to the store he asked me to pay him back
# PROMPT:  Struggling to understand a complex concept. Feeling confused and...
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  i am sure it will not be an awful person to help you
# PROMPT:  Aced a surprise quiz! Feeling joyful and...
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# CHATBOT :  it was a great feeling to have a good time
# PROMPT:  Feeling envious of a friend's exciting internship.
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# ...
# PROMPT:  Feeling nostalgic about a favorite professor's retirement.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i agree with you there are a lot of people in the <OUT>
# PROMPT:  Feeling frustrated about a noisy dorm environment that disrupts studying.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# CHATBOT :  i agree with you its so annoying to deal with
# PROMPT:  Feeling furious about a classmate who plagiarizes in a group project.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i would be too
# PROMPT:  Feeling apprehensive about asking for a recommendation letter.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i was worried about the pharmacy tech and i noticed a lot of people noticed
# PROMPT:  Feeling impressed by a classmate's creative project presentation.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# CHATBOT :  i agree with you there are a lot of people like that
# PROMPT:  Feeling disappointed about missing out on a club event due to illness.
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# CHATBOT :  i am going to be a pharmacy today and i cant wait
# PROMPT:  Feeling anticipated about attending a career fair.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# CHATBOT :  i am feeling positive about it
# PROMPT:  Feeling disgusted by finding mold in my dorm room.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# CHATBOT :  no i am not sure what to expect to do anything
# PROMPT:  Feeling surprised by a professor remembering my name.
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# CHATBOT :  i was so proud of my father when i was a kid
# PROMPT:  Feeling nostalgic about a favorite hangout spot near campus.
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# CHATBOT :  i am sure you will be a good place to be available
# PROMPT:  Feeling ashamed of a bad grade I received.
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i am ashamed of the best times of my life
# PROMPT:  Feeling guilty about procrastinating on studying for an important exam.
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i feel like i have been in a better place in my life
# PROMPT:  Feeling hopeful about reconnecting with an old friend from high school.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am sure you will be okay
# PROMPT:  Feeling unprepared for a class presentation due to technical difficulties.
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i was so nervous and ready to go to the pharmacy today
# PROMPT:  Feeling proud after overcoming a fear of public speaking.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  that is great to hear
# PROMPT:  Feeling overwhelmed by the amount of information to learn in a short time.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  funds a power for a couple of weeks
# PROMPT:  Feeling anxious about the results of a scholarship application.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# CHATBOT :  i am sure you will be fine
# PROMPT:  Feeling hopeful about getting published in a research journal.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  i hope you get it
# PROMPT:  Feeling frustrated about a lack of sleep due to a noisy roommate.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  to be stuck on a road trip to work
# PROMPT:  Feeling disappointed about a canceled flight home for the holidays.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  i am sure you will be a good parent then
# PROMPT:  Feeling envious of a classmate's natural talent for a particular subject.
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# CHATBOT :  you will be better than the <OUT> of your career
# PROMPT:  Feeling grateful for the support of my family during a difficult time.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# CHATBOT :  came to church in a few months

# %%
responses
# Out:
# ['i am glad you are okay ',
#  'i know_comma_ i felt so bad for the first time ',
#  'i am sorry to hear that ',
#  'i am sure you will be happy for the best ',
#  'can not even if i found a hair in it ',
#  'i am excited for the new super smash bros ',
#  'i was so nervous and ready to get my grades back ',
#  'i am sure you will be fine ',
#  'i am sure you will be getting it ',
#  'i am feeling very happy and relieved to go to the pharmacy to start ',
#  'i am sure you will have a good time ',
#  'i am happy for you ',
#  'i am sure you will be fine ',
#  'how much did you get ',
#  'i hope so i think i will get the job ',
#  'i am sure you will be fine ',
#  'i feel so bad about myself ',
#  'i was shocked by a friend of mine recently ',
#  'i was feeling good about my childhood and high school ',
#  'i am sure you will do great ',
#  'i dont know why they are just being rude and they are just rude to the <OUT> ',
#  'i am going to be a bit more <OUT> but i am stuck at work ',
#  'that is awesome i wish i could be more than a year ',
#  'i am glad you are okay ',
#  'what kind of food do you have ',
#  'i am sure you will be fine ',
#  'i am sure you will be fine ',
#  'i am sure you will be proud of your future ',
#  'that is great to hear ',
#  'that is great i bet she is doing better ',
#  'i am sure it was a good thing ',
#  'that is sad i am sorry to hear that ',
#  'i am glad you are okay ',
#  'i know_comma_ i felt so bad for the first time ',
#  'i am sorry to hear that ',
#  'i am sure you will be happy for the best ',
#  'can not even if i found a hair in it ',
#  'i am excited for the new super smash bros ',
#  'i was so nervous and ready to get my grades back ',
#  'i am sure you will be fine ',
#  'i am sure you will be getting it ',
#  'i am feeling very happy and relieved to go to the pharmacy to start ',
#  'i am sure you will have a good time ',
#  'i am happy for you ',
#  'i am sure you will be fine ',
#  'how much did you get ',
#  'i hope so i think i will get the job ',
#  'i am sure you will be fine ',
#  'i feel so bad about myself ',
#  'i was shocked by a friend of mine recently ',
#  'i was feeling good about my childhood and high school ',
#  'i am sure you will do great ',
#  'i dont know why they are just being rude and they are just rude to the <OUT> ',
#  'i am going to be a bit more <OUT> but i am stuck at work ',
#  'that is awesome i wish i could be more than a year ',
#  'i am glad you are okay ',
#  'what kind of food do you have ',
#  'i am sure you will be fine ',
#  'i am sure you will be fine ',
#  'i am sure you will be proud of your future ',
#  'that is great to hear ',
#  'that is great i bet she is doing better ',
#  'i am sure it was a good thing ',
#  'that is sad i am sorry to hear that ',
#  'can be so hard to deal with ',
#  'i am sorry to hear that ',
#  'report him to the store he asked me to pay him back ',
#  'i am sure it will not be an awful person to help you ',
#  'it was a great feeling to have a good time ',
#  'i am sure you will be getting a big one ',
#  'i am sure you will be happy for you ',
#  'right true ',
#  'i am glad to hear that what kind of work do ',
#  'i know the feeling i have been there for the last couple of months and i feel so bad for the <PAD> <PAD> <PAD> ',
#  'employee of work for a party for my job_comma_ and i am not sure if i will not <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> ',
#  'i am so proud of myself ',
#  'i am sure you will find something soon ',
#  'hopefully they will not be able to get it ',
#  'i hope so too ',
#  'i am sure you will be fine ',
#  'i feel kinda bad about myself ',
#  'that is awesome what kind of music ',
#  'i agree with you i wish you all the best of your youth ',
#  'i know it was hard but i think i will get the promotion ',
#  'i am sorry to hear that ',
#  'i am sorry to hear that ',
#  'that is awesome i wish i could be more considerate of others ',
#  'that is great to hear ',
#  'i was so embarrassed when i saw my dog poop on the floor ',
#  'i understand that_comma_ it happens to me ',
#  'i hope so too ',
#  'i have a friend who has been in a <OUT> place in a row in the city ',
#  'is it a big deal ',
#  'that is great_comma_ it is a lot of people who have to protect us ',
#  'i am sure he will be able to take a break from work ',
#  'i worked hard for it ',
#  'i am glad you have a great time ',
#  'i am beyond thankful for my life ',
#  'area with the kids through the new job ',
#  'i am glad you are feeling better now ',
#  'i am sorry_comma_ i am sorry to hear that ',
#  'i am glad to hear that you are right now ',
#  'i am sure you will be able to get a new job ',
#  'i am sure you will be fine ',
#  'i am proud of her ',
#  'i am sure it will be alright ',
#  'i am sure you will be fine ',
#  'i hope so i think i will get the job ',
#  'i was in the <OUT> for a while <OUT> i was so nervous ',
#  'i am feeling a bit upset about it ',
#  'green <OUT> <OUT> <OUT> ',
#  'i was feeling good about my childhood last year of high school ',
#  'no but i am not sure how to deal with it ',
#  'i am so upset about it ',
#  'i am sure you will be okay ',
#  'i am glad you were able to help you ',
#  'i am sure you will be a good guy ',
#  'i would have been so embarrassed ',
#  'job for sure ',
#  'i am sure you will be in the future ',
#  'i am sure you will have a good time ',
#  'i am sure you will be fine ',
#  'i am so hopeful for the future of the world ',
#  'i am so sorry to hear that ',
#  'i had to get an a <OUT> <OUT> and my girlfriend was born in the <OUT> so i was so happy ',
#  'i am sure you will be fine ',
#  'we are going to church to our country ',
#  'i hope so too ',
#  'i am feeling very positive about it ',
#  'i am sorry to hear that ',
#  'i understand it was a hard time to get in the <OUT> and the best of luck ',
#  'i am sure it was an accounting test ',
#  'i am sure you will be fine ',
#  'i agree with you ',
#  'i am sure it will be a good feeling for you ',
#  'i am sure you will be fine ',
#  'i hope so too ',
#  'i hope you do well ',
#  'i feel really bad about it i feel like i have been feeling about it since i was a pharmacy and i feel really ',
#  'green <OUT> <OUT> <OUT> in front of me ',
#  'i loved it as a kid i was in the 90s and it was a nice feeling ',
#  'i am glad you are feeling better ',
#  'i agree with you ',
#  'i am sure you will be able to get some rest in the future ',
#  'i am sorry to hear that ',
#  'that is good to hear what kind of job is it ',
#  'mental illness with a lot of mental illness and i dont know what to do ',
#  'scheduled for 40 ',
#  'i am sure that will be a good thing for you ',
#  'i am sorry_comma_ i hope you have a good time ',
#  'pharmacy tech <OUT> <OUT> <OUT> etc ',
#  'i am sure it will be alright ',
#  'i am sure he will be okay ',
#  'i am so happy for you ',
#  'envious i am envious of my friends ',
#  'i am sure you will be happy for you ',
#  'i hope you have a good time ',
#  'i bet you are tired ',
#  'area for work and a few hours away from work ',
#  'i am feeling a bit worried about the weekend ',
#  'i am going to have a job interview today ',
#  'i am sure you will be alright ',
#  'school and a few months ago_comma_ it was a big moment ',
#  'i am feeling a bit worried about the outcome of my life ',
#  'i am so ready for the new school ',
#  'i hope you do well ',
#  'i am sure you will be alright ',
#  'drank sometimes as a child ',
#  'best friend ',
#  'i agree with you there are a lot of people in the <OUT> ',
#  'i agree with you its so annoying to deal with ',
#  'i would be too ',
#  'i was worried about the pharmacy tech and i noticed a lot of people noticed ',
#  'i agree with you there are a lot of people like that ',
#  'i am going to be a pharmacy today and i cant wait ',
#  'i am feeling positive about it ',
#  'no i am not sure what to expect to do anything ',
#  'i was so proud of my father when i was a kid ',
#  'i am sure you will be a good place to be available ',
#  'i am ashamed of the best times of my life ',
#  'i feel like i have been in a better place in my life ',
#  'i am sure you will be okay ',
#  'i was so nervous and ready to go to the pharmacy today ',
#  'that is great to hear ',
#  'funds a power for a couple of weeks ',
#  'i am sure you will be fine ',
#  'i hope you get it ',
#  'to be stuck on a road trip to work ',
#  'i am sure you will be a good parent then ',
#  'you will be better than the <OUT> of your career ',
#  'came to church in a few months ']

# %%
analysis_dataset['response'] = responses
analysis_dataset['emotionally_supportive'] = pd.Series(dtype='int')
analysis_dataset.head()
# Out:
#                                               prompt    context  \
# 0  Bombed the presentation. Feeling terrified of ...  Terrified
# 1   Aced a difficult exam! Feeling joyful and proud.     Joyful
# 2            Feeling lonely and isolated in my dorm.     Lonely
# 3            Grateful for the support of my friends.   Grateful
# 4  Feeling disgusted by a mess someone left in th...  Disgusted
#
#                                           response  emotionally_supportive
# 0                          i am glad you are okay                      NaN
# 1  i know_comma_ i felt so bad for the first time                      NaN
# 2                         i am sorry to hear that                      NaN
# 3        i am sure you will be happy for the best                      NaN
# 4            can not even if i found a hair in it                      NaN

# %%
analysis_dataset.to_csv('analysis_responses.csv', index=False)
